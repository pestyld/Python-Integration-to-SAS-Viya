# %% [markdown]
# # Loading a CAS Action Set
# [Getting Started with Python Integration to SAS® Viya® - Part 3 - Loading a CAS Action Set](https://blogs.sas.com/content/sgf/2020/07/07/getting-started-with-python-integration-to-sas-viya-part-3-loading-a-cas-action-set/) blog post

# %% [markdown]
# ## Import Packages
# Visit the documentation for the SWAT [(SAS Scripting Wrapper for Analytics Transfer)](https://sassoftware.github.io/python-swat/index.html) package.

# %%
import swat
import pandas as pd

## custom personal module to connect to my CAS server environment
from casConnect import connect_to_cas

# %% [markdown]
# ## Make a Connection to CAS
#
# ##### To connect to the CAS server you will need:
# 1. the host name,
# 2. the portnumber,
# 3. your user name, and your password.
#
# Visit the documentation [Getting Started with SAS® Viya® for Python](https://go.documentation.sas.com/doc/en/pgmsascdc/default/caspg3/titlepage.htm) for more information about connecting to CAS.
#
# **Be aware that connecting to the CAS server can be implemented in various ways, so you might need to see your system administrator about how to make a connection. Please follow company policy regarding authentication.**

# %%
##
## Connect to CAS
##

## General connection syntax
# conn = swat.CAS(host, port, username, password)

## Viya for Learners 3.5 connection
# hostValue = os.environ.get('CASHOST')
# portValue = os.environ.get('CASPORT')
# passwordToken=os.environ.get('SAS_VIYA_TOKEN')
# conn = swat.CAS(hostname=hostValue, port=portValue, password=passwordToken)

## Personal connection
try:
    conn = connect_to_cas()
    print('CAS connection succesful')
    print(conn)
except:
    print('No connection')
    pass
# Out:
# swat.cas.connection.CAS

# %% [markdown]
# ## Exploring CAS Action Sets

# %%
conn.actionsetinfo()['setinfo']
# Out:
# Action set information
#
#          actionset               label  loaded  extension             version product_name user_defined
# 0    accessControl     Access Controls       1     tkacon  V.04.00M0P09192022        tkcas        false
# 1    accessControl     Access Controls       1    casmeta  V.04.00M0P09192022        tkcas        false
# 2         builtins            Builtins       1  tkcasablt  V.04.00M0P09192022        tkcas        false
# 3    configuration   Server Properties       1   tkcascfg  V.04.00M0P09192022        tkcas        false
# 4   dataPreprocess     Data Preprocess       1    tktrans  V.04.00M0P09192022      crsstat        false
# 5         dataStep           DATA Step       1   datastep  V.04.00M0P09192022        tkcas        false
# 6       percentile          Percentile       1   tkcasptl  V.04.00M0P09192022      crsstat        false
# 7           sccasl         CASL Server       1   tkcaslsc  V.04.00M0P09192022        tkcas        false
# 8           search              Search       1     casidx  V.04.00M0P09192022    crssearch        false
# 9          session     Session Methods       1   tkcsessn  V.04.00M0P09192022        tkcas        false
# 10     sessionProp  Session Properties       1   tkcstate  V.04.00M0P09192022        tkcas        false
# 11          simple    Simple Analytics       1   tkimstat  V.04.00M0P09192022      crsstat        false
# 12           table               Table       1   tkcastab  V.04.00M0P09192022        tkcas        false

# %%
conn.actionsetinfo(all=True)['setinfo']
# Out:
# Action set information
#
#                     actionset               label  loaded            extension             version          product_name user_defined
# 0                      access                           0               tkacon  V.04.00M0P09192022                 tkcas        false
# 1               accessControl     Access Controls       1              casmeta  V.04.00M0P09192022                 tkcas        false
# 2                 activeLearn                           0               tkaluc  V.04.00M0P09192022          crsactivelrn        false
# 3                 aggregation                           0             tkcasagg  V.04.00M0P09192022          crsaggregate        false
# 4                      astore                           0               astore  V.04.00M0P09192022             crsastore        false
# 5                       audio                           0                audio  V.04.00M0P09192022              crsaudio        false
# 6                    autotune                           0             optminer  V.04.00M0P09192022           crsoptminer        false
# 7                        bart                           0                 bart  V.04.00M0P09192022               crsbart        false
# 8       bayesianNetClassifier                           0            tkcasbnet  V.04.00M0P09192022           crsbayesian        false
# 9                 bioMedImage                           0          biomedimage  V.04.00M0P09192022          crsbiomedimg        false
# 10                   boolRule                           0               casblr  V.04.00M0P09192022           crsboolrule        false
# 11                   builtins            Builtins       1            tkcasablt  V.04.00M0P09192022                 tkcas        false
# 12                cardinality                           0          cardinality  V.04.00M0P09192022           crscardinal        false
# 13                        cdm                           0                  cdm  V.04.00M0P09192022          crsaglossmod        false
# 14                 clustering                           0           tkcaskclus  V.04.00M0P09192022             crskmeans        false
# 15    conditionalRandomFields                           0                  crf  V.04.00M0P09192022                crscrf        false
# 16              configuration   Server Properties       1             tkcascfg  V.04.00M0P09192022                 tkcas        false
# 17                     copula                           0               copula  V.04.00M0P09192022             crscopula        false
# 18                   countreg                           0             countreg  V.04.00M0P09192022           crscountreg        false
# 19                  dataAgent                           0       tkcasdajobexec  V.04.00M0P09192022          crsdataagent        false
# 20              dataDiscovery                           0          dmdiscovery  V.04.00M0P09192022            crsprofile        false
# 21             dataPreprocess     Data Preprocess       1              tktrans  V.04.00M0P09192022               crsstat        false
# 22                dataQuality        Data Quality       0               casqkb  V.04.00M0P09192022            crsqkbmgmt        false
# 23           dataSciencePilot                           0            tkdspilot  V.04.00M0P09192022            crsdspilot        false
# 24                dataShaping                           0        tkdatashaping  V.04.00M0P09192022        crsdatashaping        false
# 25                   dataStep           DATA Step       1             datastep  V.04.00M0P09192022                 tkcas        false
# 26               decisionTree                           0              tkcasdt  V.04.00M0P09192022              crsdtree        false
# 27              deduplication                           0            casdedupe  V.04.00M0P09192022              crsdedup        false
# 28                   deepEcon                           0                  dlc  V.04.00M0P09192022           crsdeepecon        false
# 29                  deepLearn                           0                 tkdl  V.04.00M0P09192022          crsdplrnsbst        false
# 30                 deepNeural                           0              tkdldnn  V.04.00M0P09192022          crsdeepneurl        false
# 31                    deepRnn                           0              tkdlrnn  V.04.00M0P09192022            crsdeeprnn        false
# 32                 dlmodelzoo                           0           dlmodelzoo  V.04.00M0P09192022         crsdlmodelzoo        false
# 33                        ds2                           0               casds2  V.04.00M0P09192022                crsds2        false
# 34     dynamicBayesianNetwork                           0            tkdynbnet  V.04.00M0P09192022            crsdynbnet        false
# 35                        ecm                           0                  ecm  V.04.00M0P09192022          crseconcapmd        false
# 36                  entityRes                           0            entityres  V.04.00M0P09192022            crscluster        false
# 37                 espCluster                           0              espgrid  V.04.00M0P09192022          crsespclustr        false
# 38                  explainAI                           0                  xai  V.04.00M0P09192022           crsexpmodel        false
# 39                    factmac                           0            tkfactmac  V.04.00M0P09192022          crstkfactmac        false
# 40                fairAITools                           0          fairaitools  V.04.00M0P09192022        crsfairaitools        false
# 41                    fastKnn                           0              fastknn  V.04.00M0P09192022            crsfastknn        false
# 42                       fcmp                FCMP       0              fcmpact  V.04.00M0P09192022            crsfcmpact        false
# 43                     fedSql                           0            casfedsql  V.04.00M0P09192022             crsfedsql        false
# 44                    freqTab                           0                 xtab  V.04.00M0P09192022               crsfreq        false
# 45                   frontier                           0             frontier  V.04.00M0P09192022           crsfrontier        false
# 46                        gam                           0                  gam  V.04.00M0P09192022              crsgampl        false
# 47   generativeAdversarialNet                           0                tkgan  V.04.00M0P09192022          crsgenadvnet        false
# 91                 regression                           0               regcas  V.04.00M0P09192022           crsregressn        false
# 92         reinforcementLearn                           0                 tkrl  V.04.00M0P09192022          crsreinlearn        false
# 93                     riskmd                           0               riskmd  V.04.00M0P09192022            crsvriskmd        false
# 94                riskMethods                           0          riskmethods  V.04.00M0P09192022          crsrskmethod        false
# 95                riskResults                           0          riskresults  V.04.00M0P09192022          crsrskresult        false
# 96                    riskRun                           0              riskrun  V.04.00M0P09192022             crsrskrun        false
# 97                    riskSim                           0              risksim  V.04.00M0P09192022             crsrsksim        false
# 98                  robustPca                           0               tkrpca  V.04.00M0P09192022               crsrpca        false
# 99                      rteng                           0                rteng  V.04.00M0P09192022              crsrteng        false
# 100                ruleMining                           0             rulemine  V.04.00M0P09192022           crsrulemine        false
# 101                        s3                           0                   s3  V.04.00M0P09192022                 tkcas        false
# 102                  sampling                           0            tkcassamp  V.04.00M0P09192022           crssampling        false
# 103                  sandwich                           0              sandcas  V.04.00M0P09192022           crssandwich        false
# 104                    sccasl         CASL Server       1             tkcaslsc  V.04.00M0P09192022                 tkcas        false
# 105                    search              Search       1               casidx  V.04.00M0P09192022             crssearch        false
# 106           searchAnalytics                           0            tksearcha  V.04.00M0P09192022          crssearchvta        false
# 107         sentimentAnalysis                           0              cassent  V.04.00M0P09192022          crssentiment        false
# 108                   seqMine             seqMine       0            tkseqmine  V.04.00M0P09192022           crssequence        false
# 109                   session     Session Methods       1             tkcsessn  V.04.00M0P09192022                 tkcas        false
# 110               sessionProp  Session Properties       1             tkcstate  V.04.00M0P09192022                 tkcas        false
# 111                  severity                           0               sevcas  V.04.00M0P09192022           crsseverity        false
# 112                    sgComp                           0               sgcomp  V.04.00M0P09192022             crssgcomp        false
# 113                    simple    Simple Analytics       1             tkimstat  V.04.00M0P09192022               crsstat        false
# 114            simpleForecast                           0              casfors  V.04.00M0P09192022           crsforecast        false
# 115                 simSystem                           0            simsystem  V.04.00M0P09192022             crssimsys        false
# 116                 smartData                           0              tkcaskm  V.04.00M0P09192022             crssmdata        false
# 117                       smc                           0                  smc  V.04.00M0P09192022              crsseqmc        false
# 118      sparkEmbeddedProcess                           0           cassparkep  V.04.00M0P09192022            crssparkep        false
# 119                  sparseML                           0                 csml  V.04.00M0P09192022           crssparseml        false
# 120                spatialreg                           0           spatialreg  V.04.00M0P09192022            crsspatial        false
# 121                       spc                           0                tkspc  V.04.00M0P09192022                crsspc        false
# 122                       ssm                           0                  ssm  V.04.00M0P09192022    crsstatespacemodel        false
# 123       stabilityMonitoring                           0              tkcassm  V.04.00M0P09192022          crsstability        false
# 124         svDataDescription                           0                 svdd  V.04.00M0P09192022               crssvdd        false
# 125                       svm                           0              tkaasvm  V.04.00M0P09192022                crssvm        false
# 126                     table               Table       1             tkcastab  V.04.00M0P09192022                 tkcas        false
# 127            textManagement                           0             textmgmt  V.04.00M0P09192022     crstextmanagement        false
# 128                textMining                           0             castmine  V.04.00M0P09192022          crstxtmining        false
# 129                 textParse                           0             casparse  V.04.00M0P09192022              crsparse        false
# 130           textRuleDevelop                           0              ruledev  V.04.00M0P09192022          crstxtruldev        false
# 131          textRuleDiscover                           0           trdiscover  V.04.00M0P09192022          crstxtruldsc        false
# 132             textRuleScore                           0              rulesco  V.04.00M0P09192022          crstxtrulscr        false
# 133         textSummarization                           0            castxtsum  V.04.00M0P09192022            crstextsum        false
# 134                 textTopic                           0            texttopic  V.04.00M0P09192022           crstxttopic        false
# 135                  textUtil                           0             textutil  V.04.00M0P09192022            crstxtutil        false
# 136                  timeData                           0              castide  V.04.00M0P09192022           crstimedata        false
# 137               timeFilters                           0             tktimfil  V.04.00M0P09192022          crstimfilter        false
# 138             timeFrequency                           0              tkcastf  V.04.00M0P09192022           crstimefreq        false
# 139                 transpose                           0         castranspose  V.04.00M0P09192022          crstranspose        false
# 140                    tsInfo                           0               tsinfo  V.04.00M0P09192022          crstmserinfo        false
# 141                      tSne                           0                 tsne  V.04.00M0P09192022               crstsne        false
# 142               tsReconcile                           0             tkrecfor  V.04.00M0P09192022          crsreconcile        false
# 143             uniTimeSeries                           0                  cts  V.04.00M0P09192022          crsutmseries        false
# 144                 varReduce                           0           tkaareduce  V.04.00M0P09192022          crsvarreduce        false

# %% [markdown]
# ## Loading a CAS Action Set
#
# ### Find the action set

# %%
df = conn.actionsetinfo(all=True)['setinfo']
type(df)
# Out:
# swat.dataframe.SASDataFrame

# %%
df.loc[df['actionset'].str.contains('regression', case=False), :]
# Out:
# Action set information
#
#      actionset label  loaded extension             version product_name user_defined
# 91  regression             0    regcas  V.04.00M0P09192022  crsregressn        false

# %% [markdown]
# ### Load the action set

# %%
conn.loadActionSet(actionSet='regression')
# Out:
# NOTE: Added action set 'regression'.
# [actionset]
#
#  'regression'
#
# + Elapsed: 0.0201s, user: 0.0178s, sys: 0.0384s, mem: 1.32mb

# %% [markdown]
# ## Exploring CAS Actions in a CAS Action Set

# %%
conn.help(actionSet='regression')
# Out:
# NOTE: Information for action set 'regression':
# NOTE:    regression
# NOTE:       glm - Fits linear regression models using the method of least squares
# NOTE:       genmod - Fits generalized linear regression models
# NOTE:       logistic - Fits logistic regression models
# NOTE:       logisticType3 - computes Type 3 or Joint tests that all parameters for an effect are zero
# NOTE:       logisticCode - writes SAS DATA step code for computing predicted values of the fitted model
# NOTE:       genmodScore - creates a table on the server that contains results from scoring observations by using a fitted model
# NOTE:       logisticScore - creates a table on the server that contains results from scoring observations by using a fitted model
# NOTE:       glmScore - creates a table on the server that contains results from scoring observations by using a fitted model
# NOTE:       logisticAssociation - computes indices of rank correlation between predicted probabilities and observed responses used for assessing the predictive ability of a model
# NOTE:       logisticLackfit - computes the Hosmer and Lemeshow test
# NOTE:       logisticOddsRatio - creates a table that compares subpopulations by using odds ratios.
# NOTE:       modelMatrix - creates a table on the server that contains the design matrix associated with a given model statement.
# [regression]
#
#                     name                                        description
#  0                   glm  Fits linear regression models using the method...
#  1                genmod          Fits generalized linear regression models
#  2              logistic                    Fits logistic regression models
#  3         logisticType3  computes Type 3 or Joint tests that all parame...
#  4          logisticCode  writes SAS DATA step code for computing predic...
#  5           genmodScore  creates a table on the server that contains re...
#  6         logisticScore  creates a table on the server that contains re...
#  7              glmScore  creates a table on the server that contains re...
#  8   logisticAssociation  computes indices of rank correlation between p...
#  9       logisticLackfit              computes the Hosmer and Lemeshow test
#  10    logisticOddsRatio  creates a table that compares subpopulations b...
#  11          modelMatrix  creates a table on the server that contains th...
#
# + Elapsed: 0.0101s, user: 0.00891s, sys: 0.00976s, mem: 1.43mb

# %% [markdown]
# ## Terminate the CAS Connection

# %%
conn.terminate()
