# %%
## CAS Server Package
import swat

## Local Packages and Options
import os
import pandas as pd
import json
from pathlib import Path
pd.set_option('display.max_columns', None)

# %%
os.environ["CAS_CLIENT_SSL_CA_LIST"] = r"C:\Users\pestyl\OneDrive - SAS\Documents\Keys\SSEMonthly-2022.pem"

hostname = "https://ssemonthly.demo.sas.com/cas-shared-default-http/"

credentials_file = Path(r"C:\Users\pestyl\.sas\credentials.json")
credentials = json.loads(credentials_file.read_bytes())
access_token = credentials["ssemonthly"]["access-token"]

# %%
conn = swat.CAS(hostname, 443, password=access_token)

# %%
castbl = conn.read_csv(r'https://support.sas.com/documentation/onlinedoc/viya/exampledatasets/cars.csv', ## Client-side file to load into memory
                       casout = {'name':'hmeq',                                                          ## Output in-memory CAS table information
                                 'caslib':'casuser', 
                                 'replace':True})
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table HMEQ in caslib CASUSER(Peter.Styliadis@sas.com).
# NOTE: The table HMEQ has been created in caslib CASUSER(Peter.Styliadis@sas.com) from binary data uploaded to Cloud Analytic Services.

# %%
castbl.describe().round()
# Out:
#        MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# count   NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# mean    NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# std     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# min     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# 25%     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# 50%     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# 75%     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
# max     NaN      NaN         NaN        NaN         NaN       NaN          NaN     NaN        NaN     NaN
